# %% [markdown]
# ## **Data Science Aplicado a las Finanzas** 🚀
# ### **HW Sesión 4**
#
# Andrés C. Medina Sanhueza
#
# Senior Datascientist Engineer
#
# anmedinas@gmail.com

# %% [markdown]
# Consideraciones Previas
#
# * Tarea es Individual (se debe enviar la direccion de jupyter colab con permisos de edición)
#
# * Fecha Entrega : Viernes 15 de Agosto 23:59 min a `anmedinas@gmail.com`
#
# ---

# %% [markdown]
# ## 1. Aprendizaje no Supervisado
#
# Considere el dataset `creditSIM.xlsx` que contiene información de clientes de un banco. El objetivo, es poder construir perfiles o clusters de clientes de modo que, mediante estrategias de campañas de marketing, podamos otorgar tarjetas de crédito. El dataset contiene las siguientes variables:
#
# 1. ID: Numero de cliente.
# 2. AgnosDirec: Años que el cliente lleva viviendo en la misma dirección.
# 3. AgnosEmpleo: Años de antiguedad del cliente en el empleo.
# 4. DeudaExt: Deuda del cliente externa al banco
# 5. DeudaInt: Deuda del cliente en el banco. Por ejemplo, otros creditos.
# 6. Edad: Edad del cliente.
# 7. Ingreso/Ingreso2: Ingreso del cliente (recopilados de dos fuentes diferentes).
# 8. Nacionalidad: Nacionalidad del cliente.
# 9. NivelEdu: Nivel educacional del cliente.
# 10. VarObj: Variable objetivo. Si el cliente es un mal pagador ("cae en bancarrota") en caso de recibir el crédito. Si el cliente cae en bancarrota toma el valor de S y en el caso contrario N.
#
# Esta pregunta, es abierta, por lo que no hay una respuesta correcta o incorrecta. Se espera que usted explore el dataset y realice un análisis exploratorio de datos (EDA) para entender mejor la información. Luego, utilice técnicas de aprendizaje no supervisado para identificar patrones o grupos en los datos. Finalmente, presente sus hallazgos y recomendaciones.

# %%
# inserte aqui su codigo

# %% [markdown]
# ## 2. Aprendizaje Supervisado
#
# El objetivo de este ejercicio es construir un modelo de regresión supervisada (Random Forest o SVR vistos en clases) para predecir la volatilidad futura de una acción utilizando variables relevantes extraídas de series temporales financieras y variables externas.
#
# Las instrucciones detalladas son las siguientes:
#
# 1. **Descarga de datos:**
#    Descarga la serie histórica de precios de cierre y volumen de una acción de tu elección usando `yfinance` a su eleccion. Utiliza un rango de al menos 5 años de datos diarios.
#
# 2. **Construcción de variables:**
#    Debes construir las siguientes variables para alimentar tu modelo:
#
#    - **Retorno logarítmico diario:**
#      $r_t = \log(\text{Close}_t / \text{Close}_{t-1})$
#    - **Volatilidad móvil:**
#      Desviación estándar de los retornos logarítmicos en una ventana de 30 días.
#    - **Cambio porcentual de volumen:**
#      $\text{Vol\_change}_t = (\text{Volume}_t - \text{Volume}_{t-1}) / \text{Volume}_{t-1}$
#    - **Media móvil de precios:**
#      Media móvil simple de 20 días del precio de cierre.
#    - **Rezagos:**
#      Para cada variable anterior, genera al menos 5 rezagos (por ejemplo, `Lag_Return_1`, `Lag_Return_2`, ..., `Lag_Return_5`).
#    - **Volatilidad implícita (VIX):**
#      Descarga la serie histórica del índice VIX y sincronízala con las fechas de tu acción. Incluye el valor actual y al menos 5 rezagos (`Lag_VIX_1`, ..., `Lag_VIX_5`).
#    - **Variables macroeconómicas:**
#      Descarga y sincroniza al menos dos variables macro relevantes (por ejemplo, tasa de interés de EE.UU., inflación, desempleo, PIB, etc.) y genera al menos 5 rezagos para cada una.
#
# 3. **Preparación de datos:**
#    Elimine los valores nulos generados por los rezagos y ventanas móviles.
#
# 4. **Entrenamiento y evaluación:**
#    Divida los datos en conjuntos de entrenamiento y prueba respetando el orden temporal. Entrene el modelo y evalúe su desempeño usando RMSE.
#
# 5. **Visualización:**
#    Grafique la volatilidad observada vs la volatilidad estimada por el modelo en el conjunto de prueba.
#
# 6. **Benchmark**
#     Compare el desempeño de su modelo con un modelo benchmark, el modelo benchmark son los modelos GARCH(1,1) y EGARCH(1,1) vistos en clases.

# %%
# inserte aqui su codigo
