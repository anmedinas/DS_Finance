# %% [markdown]
# ## **Data Science Aplicado a las Finanzas** 🚀
# ### **Sesión 1:  Introducción a la Ciencia de Datos Financieros**
#
# Andrés C. Medina Sanhueza
#
# Senior Datascientist Engineer
#
# anmedinas@gmail.com

# %% [markdown]
# ## 1. Datascience en Finanzas

# %% [markdown]
# ## 2. Entornos

# %% [markdown]
# ## 3. Estructura de Proyecto

# %% [markdown]
# ## 4. Github

# %% [markdown]
# ## 5. TO-DO
